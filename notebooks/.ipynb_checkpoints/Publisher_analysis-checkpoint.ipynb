# %%
#Publisher analysis
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw_analyst_ratings.csv')

# %%
publisher_counts = df['publisher'].value_counts().head(5).sort_values(ascending=False)

# %%
plt.figure(figsize=(12, 6))
ax = publisher_counts.plot(kind='bar', color='steelblue')
ax.set_xlabel('Publisher')
ax.set_ylabel('Number of Articles')
ax.set_title('Publisher Contribution to News Feed')
ax.set_xticklabels(publisher_counts.index, rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_publishers = publisher_counts.head(5).index
subset_data = df[df['publisher'].isin(top_publishers)]

# %%
for publisher in top_publishers:
    publisher_data = subset_data[subset_data['publisher'] == publisher]
    print(publisher_data)
# Out:
#          Unnamed: 0                                           headline  \
# 209             209  Agilent Reports Purchase Of Genohm, No Terms D...
# 212             212  UPDATE: Alnylam, Agilent Deal Has Initial Term...
# 213             213  Alnylam Pharma 8-K Shows Co. Entered Manufactu...
# 225             225  Agilent Reports Purchase Of Luxcel Biosciences...
# 233             233  Agilent Sees Q1 Adj. EPS $0.55-$0.57 vs $0.60 ...
# ...             ...                                                ...
# 1407290     1413811  China Zenix Auto Int'l Reports Q2 Loss $0.01, ...
# 1407293     1413814  China Zenix Auto Q1 EPS $0.00, Revenue $116.5M...
# 1407304     1413825  China Zenix Auto International Limited Reports...
# 1407311     1413832  China Zenix Auto Shares Halted on NYSE Just Fo...
# 1407313     1413834  China Zenix Auto International Limited Reports...
#
#                                                        url      publisher  \
# 209      https://www.benzinga.com/news/m-a/18/05/116317...  Paul Quintaro
# 212      https://www.benzinga.com/news/18/04/11464543/u...  Paul Quintaro
# 213      https://www.benzinga.com/news/18/04/11464538/a...  Paul Quintaro
# 225      https://www.benzinga.com/news/m-a/18/01/110067...  Paul Quintaro
# 233      https://www.benzinga.com/news/guidance/17/11/1...  Paul Quintaro
# ...                                                    ...            ...
# 1407290  https://www.benzinga.com/news/earnings/15/08/5...  Paul Quintaro
# 1407293  https://www.benzinga.com/news/earnings/15/05/5...  Paul Quintaro
# 1407304  https://www.benzinga.com/news/earnings/14/08/4...  Paul Quintaro
# 1407311  https://www.benzinga.com/news/13/11/4106696/ch...  Paul Quintaro
# 1407313  https://www.benzinga.com/news/earnings/13/03/3...  Paul Quintaro
#
#                         date stock
# 209      2018-05-02 00:00:00     A
# 212      2018-04-03 00:00:00     A
# 213      2018-04-03 00:00:00     A
# 225      2018-01-09 00:00:00     A
# 233      2017-11-20 00:00:00     A
# ...                      ...   ...
# 1407290  2015-08-19 00:00:00    ZX
# 1407293  2015-05-19 00:00:00    ZX
# 1407304  2014-08-21 00:00:00    ZX
# 1407311  2013-11-25 00:00:00    ZX
# 1407313  2013-03-21 00:00:00    ZX
#
# [228373 rows x 6 columns]
#          Unnamed: 0                                           headline  \
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 9                 9         10 Biggest Price Target Changes For Friday
# 10               10    30 Stocks Moving in Friday's Pre-Market Session
# 15               15                Earnings Scheduled For May 21, 2020
# ...             ...                                                ...
# 1407300     1413821  5 Consumer Goods Stocks With The Lowest PEG Ratio
# 1407303     1413824  5 Consumer Goods Stocks With The Lowest PEG Ratio
# 1407315     1413836      Top Narrow Based Indexes For January 10, 2013
# 1407316     1413837   A Peek Into The Market Before The Trading Starts
# 1407319     1413840  5 Auto Parts Stocks With The Highest Operating...
#
#                                                        url   publisher  \
# 2        https://www.benzinga.com/news/20/05/16103463/7...  Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...  Lisa Levin
# 9        https://www.benzinga.com/analyst-ratings/price...  Lisa Levin
# 10       https://www.benzinga.com/news/20/05/16092879/3...  Lisa Levin
# 15       https://www.benzinga.com/news/earnings/20/05/1...  Lisa Levin
# ...                                                    ...         ...
# 1407300  https://www.benzinga.com/trading-ideas/14/11/4...  Lisa Levin
# 1407303  https://www.benzinga.com/trading-ideas/14/09/4...  Lisa Levin
# 1407315  https://www.benzinga.com/news/13/01/3232441/to...  Lisa Levin
# 1407316  https://www.benzinga.com/news/12/12/3189703/a-...  Lisa Levin
# 1407319  https://www.benzinga.com/trading-ideas/12/07/2...  Lisa Levin
#
#                               date stock
# 2        2020-05-26 04:30:07-04:00     A
# 3        2020-05-22 12:45:06-04:00     A
# 9        2020-05-22 08:06:17-04:00     A
# 10             2020-05-22 00:00:00     A
# 15             2020-05-21 00:00:00     A
# ...                            ...   ...
# 1407300        2014-11-11 00:00:00    ZX
# 1407303        2014-09-02 00:00:00    ZX
# 1407315        2013-01-10 00:00:00    ZX
# 1407316        2012-12-20 00:00:00    ZX
# 1407319        2012-07-30 00:00:00    ZX
#
# [186979 rows x 6 columns]
#          Unnamed: 0                                           headline  \
# 7                 7  Agilent Technologies shares are trading higher...
# 13               13  Agilent Technologies shares are trading higher...
# 14               14  Agilent Technologies Q2 Adj. EPS $0.71 Beats $...
# 18               18  Pershing Square 13F Shows Fund Raises Stake In...
# 20               20  Shares of several healthcare companies are tra...
# ...             ...                                                ...
# 1406462     1412983  Zumiez Q1 EPS $(0.10) Beats $(0.14) Estimate, ...
# 1406465     1412986  Wedbush Initiates Coverage On Zumiez with Neut...
# 1407261     1413782  China Zenix Auto International Announces Inten...
# 1407262     1413783        China Zenix Auto Shares Halted News Pending
# 1407263     1413784  China Zenix Auto Q1 EPS $0.08, Made $130.123M ...
#
#                                                        url          publisher  \
# 7        https://www.benzinga.com/wiim/20/05/16093805/a...  Benzinga Newsdesk
# 113      2019-08-01 00:00:00     A
# 155      2019-01-29 00:00:00     A
# 174      2018-09-26 00:00:00     A
# 215      2018-03-07 00:00:00     A
# 221      2018-02-13 00:00:00     A
# ...                      ...   ...
# 1407307  2014-02-24 00:00:00    ZX
# 1407308  2013-12-23 00:00:00    ZX
# 1407309  2013-12-09 00:00:00    ZX
# 1407312  2013-11-25 00:00:00    ZX
# 1407317  2012-12-20 00:00:00    ZX
#
# [96732 rows x 6 columns]
#          Unnamed: 0                                           headline  \
# 307             307       10 Biggest Price Target Changes For Thursday
# 309             309  20 Stocks Moving In Thursday's Pre-Market Session
# 311             311             10 Stocks To Watch For August 18, 2016
# 316             316             12 Stocks You Should Be Watching Today
# 317             317             Earnings Scheduled For August 17, 2016
# ...             ...                                                ...
# 1407299     1413820           Earnings Scheduled For November 13, 2014
# 1407310     1413831                        Stocks Hitting 52-Week Lows
# 1407314     1413835              Earnings Scheduled For March 21, 2013
# 1407318     1413839             Earnings Scheduled For August 22, 2012
# 1407323     1413844             Top Narrow Based Indexes For August 29
#
#                                                        url      publisher  \
# 307      https://www.benzinga.com/analyst-ratings/price...  Monica Gerson
# 309      https://www.benzinga.com/news/16/08/8367311/20...  Monica Gerson
# 311      https://www.benzinga.com/news/earnings/16/08/8...  Monica Gerson
# 316      https://www.benzinga.com/news/earnings/16/08/8...  Monica Gerson
# 317      https://www.benzinga.com/news/earnings/16/08/8...  Monica Gerson
# ...                                                    ...            ...
# 1407299  https://www.benzinga.com/news/earnings/14/11/5...  Monica Gerson
# 1407310  https://www.benzinga.com/news/13/11/4117449/st...  Monica Gerson
# 1407314  https://www.benzinga.com/news/earnings/13/03/3...  Monica Gerson
# 1407318  https://www.benzinga.com/news/earnings/12/08/2...  Monica Gerson
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...  Monica Gerson
#
#                         date stock
# 307      2016-08-18 00:00:00     A
# 309      2016-08-18 00:00:00     A
# 311      2016-08-18 00:00:00     A
# 316      2016-08-17 00:00:00     A
# 317      2016-08-17 00:00:00     A
# ...                      ...   ...
# 1407299  2014-11-13 00:00:00    ZX
# 1407310  2013-11-29 00:00:00    ZX
# 1407314  2013-03-21 00:00:00    ZX
# 1407318  2012-08-22 00:00:00    ZX
# 1407323  2011-08-29 00:00:00    ZX
#
# [82380 rows x 6 columns]

# %%
import re

# %%
def extract_domain(email):
    match = re.search("@[\w.]+", email)
    if match:
        return match.group()[1:]
    else:
        return None

# %%
df['domain'] = df['publisher'].apply(extract_domain)
domain_counts = df['domain'].value_counts()

# %%
plt.figure(figsize=(12, 6))
domain_counts.plot(kind='bar')
plt.xlabel('Domain')
plt.ylabel('Number of Contributions')
plt.title('Domain Contribution to News Feed')
plt.xticks(rotation=45)
plt.show()
